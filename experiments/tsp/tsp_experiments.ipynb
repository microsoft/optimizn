# %%
# Copyright (c) Microsoft Corporation.
# Licensed under the MIT License.

# %%
from experiments.tsp.tsp_experiments import run_tsp_experiments

# %%
exp1_results = run_tsp_experiments(50, 1, 3)
# Out:
# Initial solution: [ 0 36 31 32 15 24  9 49 47 33 26 46 42 29 48 37  5 22 27 10 18  8  6 25
#   7 16 44 39 28 21  4 43 11 38 23 12 13 45 40 19 34 30  3 35  2 14 41 17
#   1 20]
# Initial solution cost: 160.2600282215877
# Iteration: 0 Current best solution: 160.2600282215877
# Best cost updated to:159.16189378947175
# Best cost updated to:158.85538817666298
# Best cost updated to:156.4473609031319
# Best cost updated to:156.38212254934626
# Best cost updated to:156.18148028072767
# Best cost updated to:156.03572959585438
# Best cost updated to:154.81520530806947
# Best cost updated to:154.1653351782298
# Best cost updated to:153.83684403985617
# Best cost updated to:153.50793035434404
# Best cost updated to:152.5816393144721
# Best cost updated to:151.62335290796818
# Best cost updated to:151.12534761374434
# Best cost updated to:148.74512643009274
# Best cost updated to:147.43499486655105
# Best cost updated to:147.1769264628653
# Best cost updated to:145.95859947257168
# ...

# %%
exp1_results
# Out:
# {'sa1': [136.188704476725, 136.188704476725, 136.188704476725],
#  'sa1_time': [60.00008225440979, 60.00051498413086, 60.00052285194397],
#  'sa2': [129.27368530421433, 129.27368530421433, 129.27368530421433],
#  'sa2_time': [60.00416612625122, 60.00347828865051, 60.004088163375854],
#  'trad_bnb': [160.2600282215877, 160.2600282215877, 160.2600282215877],
#  'trad_bnb_time': [61.22933101654053, 60.11674952507019, 60.14792799949646],
#  'mod_bnb': [140.92223039505961, 140.92223039505961, 140.92223039505961],
#  'mod_bnb_time': [60.00835394859314, 60.11914682388306, 60.14324498176575],
#  'sa1_init_sol': array([ 0, 36, 31, 32, 15, 24,  9, 49, 47, 33, 26, 46, 42, 29, 48, 37,  5,
#         22, 27, 10, 18,  8,  6, 25,  7, 16, 44, 39, 28, 21,  4, 43, 11, 38,
#         23, 12, 13, 45, 40, 19, 34, 30,  3, 35,  2, 14, 41, 17,  1, 20]),
#  'sa1_init_sol_cost': 160.2600282215877,
#  'sa2_init_sol': [0,
#   36,
#   31,
#   32,
#   15,
#   24,
#   9,
#   49,
#   47,
#   33,
#   26,
#   46,
# ...

# %%
exp1_results['sa1_init_sol_cost'], exp1_results['sa1_init_sol']
# Out:
# (160.2600282215877,
#  array([ 0, 36, 31, 32, 15, 24,  9, 49, 47, 33, 26, 46, 42, 29, 48, 37,  5,
#         22, 27, 10, 18,  8,  6, 25,  7, 16, 44, 39, 28, 21,  4, 43, 11, 38,
#         23, 12, 13, 45, 40, 19, 34, 30,  3, 35,  2, 14, 41, 17,  1, 20]))

# %%
exp1_results['sa2_init_sol_cost'], exp1_results['sa2_init_sol']
# Out:
# (160.2600282215877,
#  [0,
#   36,
#   31,
#   32,
#   15,
#   24,
#   9,
#   49,
#   47,
#   33,
#   26,
#   46,
#   42,
#   29,
#   48,
#   37,
#   5,
#   22,
#   27,
#   10,
#   18,
#   8,
#   6,
#   25,
#   7,
#   16,
#   44,
#   39,
#   28,
#   21,
#   4,
#   43,
#   11,
#   38,
#   23,
#   12,
#   13,
#   45,
#   40,
#   19,
#   34,
#   30,
#   3,
#   35,
#   2,
#   14,
#   41,
#   17,
#   1,
#   20])

# %%
exp1_results['trad_bnb_init_sol_cost'], exp1_results['trad_bnb_init_sol']
# Out:
# (160.2600282215877,
#  ([0,
#    36,
#    31,
#    32,
#    15,
#    24,
#    9,
#    49,
#    47,
#    33,
#    26,
#    46,
#    42,
#    29,
#    48,
#    37,
#    5,
#    22,
#    27,
#    10,
#    18,
#    8,
#    6,
#    25,
#    7,
#    16,
#    44,
#    39,
#    28,
#    21,
#    4,
#    43,
#    11,
#    38,
#    23,
#    12,
#    13,
#    45,
#    40,
#    19,
#    34,
#    30,
#    3,
#    35,
#    2,
#    14,
#    41,
#    17,
#    1,
#    20],
#   -1))

# %%
exp1_results['mod_bnb_init_sol_cost'], exp1_results['mod_bnb_init_sol']
# Out:
# (160.2600282215877,
#  ([0,
#    36,
#    31,
#    32,
#    15,
#    24,
#    9,
#    49,
#    47,
#    33,
#    26,
#    46,
#    42,
#    29,
#    48,
#    37,
#    5,
#    22,
#    27,
#    10,
#    18,
#    8,
#    6,
#    25,
#    7,
#    16,
#    44,
#    39,
#    28,
#    21,
#    4,
#    43,
#    11,
#    38,
#    23,
#    12,
#    13,
#    45,
#    40,
#    19,
#    34,
#    30,
#    3,
#    35,
#    2,
#    14,
#    41,
#    17,
#    1,
#    20],
#   -1))

# %%
exp2_results = run_tsp_experiments(100, 2, 3)
# Out:
# Initial solution: [ 0 55 76 57 92 10 61 36 65 44 89 54 45 94 62 33 19 11 50  3 96 71 40 42
#  47 58 85 60 72 87 74  1  5 97  6 88 39 80 68 95 32 14 99 70 27 51 64  7
#  17 15 31 25 98 91 86  9 73 93 21  2 59 23 67 52  4 37 30 49 63 75 83  8
#  79 28 34 43 66 84 22 48 53 41 78 12 18 35 20 82 13 77 24 29 38 81 56 26
#  16 46 90 69]
# Initial solution cost: 204.2780645916166
# Iteration: 0 Current best solution: 204.2780645916166
# Best cost updated to:203.48540601723278
# Best cost updated to:203.1175259318793
# Best cost updated to:202.81851533058443
# Best cost updated to:202.32133208047875
# Best cost updated to:201.83691519552
# Best cost updated to:201.3664890180016
# Best cost updated to:201.09165496416003
# Best cost updated to:200.79608482004014
# Best cost updated to:200.43379998615845
# Best cost updated to:200.13924152284582
# Best cost updated to:199.47333484900835
# Iteration: 10000 Current best solution: 199.47333484900835
# Resetting candidate solution.
# ...

# %%
exp2_results
# Out:
# {'sa1': [199.47333484900835, 199.47333484900835, 199.47333484900835],
#  'sa1_time': [120.00039935112, 120.00031900405884, 120.0009069442749],
#  'sa2': [196.76808475297966, 191.77911491848397, 191.77911491848397],
#  'sa2_time': [120.00686955451965, 120.00624322891235, 120.00642323493958],
#  'trad_bnb': [204.2780645916166, 204.2780645916166, 204.2780645916166],
#  'trad_bnb_time': [120.10978436470032, 120.28378319740295, 120.2412326335907],
#  'mod_bnb': [191.16579722792343, 191.16579722792343, 191.16579722792343],
#  'mod_bnb_time': [120.03035569190979, 120.12180948257446, 120.31274390220642],
#  'sa1_init_sol': array([ 0, 55, 76, 57, 92, 10, 61, 36, 65, 44, 89, 54, 45, 94, 62, 33, 19,
#         11, 50,  3, 96, 71, 40, 42, 47, 58, 85, 60, 72, 87, 74,  1,  5, 97,
#          6, 88, 39, 80, 68, 95, 32, 14, 99, 70, 27, 51, 64,  7, 17, 15, 31,
#         25, 98, 91, 86,  9, 73, 93, 21,  2, 59, 23, 67, 52,  4, 37, 30, 49,
# ...

# %%
exp2_results['sa1_init_sol_cost'], exp2_results['sa1_init_sol']
# Out:
# (204.2780645916166,
#  array([ 0, 55, 76, 57, 92, 10, 61, 36, 65, 44, 89, 54, 45, 94, 62, 33, 19,
#         11, 50,  3, 96, 71, 40, 42, 47, 58, 85, 60, 72, 87, 74,  1,  5, 97,
#          6, 88, 39, 80, 68, 95, 32, 14, 99, 70, 27, 51, 64,  7, 17, 15, 31,
#         25, 98, 91, 86,  9, 73, 93, 21,  2, 59, 23, 67, 52,  4, 37, 30, 49,
#         63, 75, 83,  8, 79, 28, 34, 43, 66, 84, 22, 48, 53, 41, 78, 12, 18,
#         35, 20, 82, 13, 77, 24, 29, 38, 81, 56, 26, 16, 46, 90, 69]))

# %%
exp2_results['sa2_init_sol_cost'], exp2_results['sa2_init_sol']
# Out:
# (204.2780645916166,
#  [0,
#   55,
#   76,
#   57,
#   92,
#   10,
#   61,
#   36,
#   65,
#   44,
#   89,
#   54,
#   45,
#   94,
#   62,
#   33,
#   19,
#   11,
#   50,
#   3,
#   96,
#   71,
#   40,
#   42,
#   47,
#   58,
#   85,
#   60,
#   72,
#   87,
#   74,
#   1,
#   5,
#   97,
#   6,
#   88,
#   39,
#   80,
#   68,
#   95,
#   32,
#   14,
#   99,
#   70,
#   27,
#   51,
#   64,
#   7,
#   17,
#   15,
#   31,
#   25,
#   98,
#   91,
#   86,
#   9,
#   73,
#   93,
#   21,
#   2,
#   59,
#   23,
#   67,
#   52,
#   4,
#   37,
#   30,
#   49,
#   63,
#   75,
#   83,
#   8,
#   79,
#   28,
#   34,
#   43,
#   66,
#   84,
#   22,
#   48,
#   53,
#   41,
#   78,
#   12,
#   18,
#   35,
#   20,
#   82,
#   13,
#   77,
#   24,
#   29,
#   38,
#   81,
#   56,
#   26,
#   16,
#   46,
#   90,
#   69])

# %%
exp2_results['trad_bnb_init_sol_cost'], exp2_results['trad_bnb_init_sol']
# Out:
# (204.2780645916166,
#  ([0,
#    55,
#    76,
#    57,
#    92,
#    10,
#    61,
#    36,
#    65,
#    44,
#    89,
#    54,
#    45,
#    94,
#    62,
#    33,
#    19,
#    11,
#    50,
#    3,
#    96,
#    71,
#    40,
#    42,
#    47,
#    58,
#    85,
#    60,
#    72,
#    87,
#    74,
#    1,
#    5,
#    97,
#    6,
#    88,
#    39,
#    80,
#    68,
#    95,
#    32,
#    14,
#    99,
#    70,
#    27,
#    51,
#    64,
#    7,
#    17,
#    15,
#    31,
#    25,
#    98,
#    91,
#    86,
#    9,
#    73,
#    93,
#    21,
#    2,
#    59,
#    23,
#    67,
#    52,
#    4,
#    37,
#    30,
#    49,
#    63,
#    75,
#    83,
#    8,
#    79,
#    28,
#    34,
#    43,
#    66,
#    84,
#    22,
#    48,
#    53,
#    41,
#    78,
#    12,
#    18,
#    35,
#    20,
#    82,
#    13,
#    77,
#    24,
#    29,
#    38,
#    81,
#    56,
#    26,
#    16,
#    46,
#    90,
#    69],
#   -1))

# %%
exp2_results['mod_bnb_init_sol_cost'], exp2_results['mod_bnb_init_sol']
# Out:
# (204.2780645916166,
#  ([0,
#    55,
#    76,
#    57,
#    92,
#    10,
#    61,
#    36,
#    65,
#    44,
#    89,
#    54,
#    45,
#    94,
#    62,
#    33,
#    19,
#    11,
#    50,
#    3,
#    96,
#    71,
#    40,
#    42,
#    47,
#    58,
#    85,
#    60,
#    72,
#    87,
#    74,
#    1,
#    5,
#    97,
#    6,
#    88,
#    39,
#    80,
#    68,
#    95,
#    32,
#    14,
#    99,
#    70,
#    27,
#    51,
#    64,
#    7,
#    17,
#    15,
#    31,
#    25,
#    98,
#    91,
#    86,
#    9,
#    73,
#    93,
#    21,
#    2,
#    59,
#    23,
#    67,
#    52,
#    4,
#    37,
#    30,
#    49,
#    63,
#    75,
#    83,
#    8,
#    79,
#    28,
#    34,
#    43,
#    66,
#    84,
#    22,
#    48,
#    53,
#    41,
#    78,
#    12,
#    18,
#    35,
#    20,
#    82,
#    13,
#    77,
#    24,
#    29,
#    38,
#    81,
#    56,
#    26,
#    16,
#    46,
#    90,
#    69],
#   -1))

# %%
exp3_results = run_tsp_experiments(200, 4, 3)
# Out:
# Initial solution: [  0 107  95  14 162 183  71  25 128 150 176  92 170 166 153  87  73  67
#   98 116 102 192  75 122  77 136 181  46 127   7  70  93   3 197  55  33
#  145 187 156 186 168  18  76  44 185  32 105 158  20 109  57 177  39 131
#   26 178 111   2  91  96 196 188 174 198  79  23  42 130  99 135 157  31
#  142 139  52 190  11 124  19 118  88 120  53  15 175  51  38 146   6  16
#  182 100  78 106  47  86   4  58  48 184 126  34 161 171 138 159  69 151
#   22  17  66 125 103 104 172 199 137  50 160  68  30  64  37 155  28  40
#  149 167  41  81  89 121  43  10 189 163 179   1  80 193 134 173  56  36
#  140  83  65 148  54 132  72  82 113  74 123  49 115 141 152  84  35  27
#  154 112   5 108  62 114 110 195 194  59 169  97  94 133 129  24  12  90
#    9  21 119  85 191 165  45  13 147 101  61 144 164  63   8 117  29 180
#   60 143]
# Initial solution cost: 334.6501715525889
# Iteration: 0 Current best solution: 334.6501715525889
# Best cost updated to:334.6186306956051
# ...

# %%
exp3_results
# Out:
# {'sa1': [329.8112753008895, 329.8112753008895, 329.8112753008895],
#  'sa1_time': [240.00088381767273, 240.00067377090454, 240.0007827281952],
#  'sa2': [325.9533572053451, 325.9533572053451, 325.1902036083636],
#  'sa2_time': [240.0126509666443, 240.02111077308655, 240.01920247077942],
#  'trad_bnb': [334.6501715525889, 334.6501715525889, 334.6501715525889],
#  'trad_bnb_time': [240.15289878845215, 240.2804901599884, 240.36329054832458],
#  'mod_bnb': [294.1086115385683, 294.1086115385683, 294.1086115385683],
#  'mod_bnb_time': [240.05983686447144, 240.18095350265503, 250.56382822990417],
#  'sa1_init_sol': array([  0, 107,  95,  14, 162, 183,  71,  25, 128, 150, 176,  92, 170,
#         166, 153,  87,  73,  67,  98, 116, 102, 192,  75, 122,  77, 136,
#         181,  46, 127,   7,  70,  93,   3, 197,  55,  33, 145, 187, 156,
#         186, 168,  18,  76,  44, 185,  32, 105, 158,  20, 109,  57, 177,
#          39, 131,  26, 178, 111,   2,  91,  96, 196, 188, 174, 198,  79,
# ...

# %%
exp3_results['sa1_init_sol_cost'], exp3_results['sa1_init_sol']
# Out:
# (334.6501715525889,
#  array([  0, 107,  95,  14, 162, 183,  71,  25, 128, 150, 176,  92, 170,
#         166, 153,  87,  73,  67,  98, 116, 102, 192,  75, 122,  77, 136,
#         181,  46, 127,   7,  70,  93,   3, 197,  55,  33, 145, 187, 156,
#         186, 168,  18,  76,  44, 185,  32, 105, 158,  20, 109,  57, 177,
#          39, 131,  26, 178, 111,   2,  91,  96, 196, 188, 174, 198,  79,
#          23,  42, 130,  99, 135, 157,  31, 142, 139,  52, 190,  11, 124,
#          19, 118,  88, 120,  53,  15, 175,  51,  38, 146,   6,  16, 182,
#         100,  78, 106,  47,  86,   4,  58,  48, 184, 126,  34, 161, 171,
#         138, 159,  69, 151,  22,  17,  66, 125, 103, 104, 172, 199, 137,
#          50, 160,  68,  30,  64,  37, 155,  28,  40, 149, 167,  41,  81,
#          89, 121,  43,  10, 189, 163, 179,   1,  80, 193, 134, 173,  56,
#          36, 140,  83,  65, 148,  54, 132,  72,  82, 113,  74, 123,  49,
#         115, 141, 152,  84,  35,  27, 154, 112,   5, 108,  62, 114, 110,
# ...

# %%
exp3_results['sa1_init_sol_cost'], exp3_results['sa1_init_sol']
# Out:
# (334.6501715525889,
#  array([  0, 107,  95,  14, 162, 183,  71,  25, 128, 150, 176,  92, 170,
#         166, 153,  87,  73,  67,  98, 116, 102, 192,  75, 122,  77, 136,
#         181,  46, 127,   7,  70,  93,   3, 197,  55,  33, 145, 187, 156,
#         186, 168,  18,  76,  44, 185,  32, 105, 158,  20, 109,  57, 177,
#          39, 131,  26, 178, 111,   2,  91,  96, 196, 188, 174, 198,  79,
#          23,  42, 130,  99, 135, 157,  31, 142, 139,  52, 190,  11, 124,
#          19, 118,  88, 120,  53,  15, 175,  51,  38, 146,   6,  16, 182,
#         100,  78, 106,  47,  86,   4,  58,  48, 184, 126,  34, 161, 171,
#         138, 159,  69, 151,  22,  17,  66, 125, 103, 104, 172, 199, 137,
#          50, 160,  68,  30,  64,  37, 155,  28,  40, 149, 167,  41,  81,
#          89, 121,  43,  10, 189, 163, 179,   1,  80, 193, 134, 173,  56,
#          36, 140,  83,  65, 148,  54, 132,  72,  82, 113,  74, 123,  49,
#         115, 141, 152,  84,  35,  27, 154, 112,   5, 108,  62, 114, 110,
# ...

# %%
exp3_results['sa2_init_sol_cost'], exp3_results['sa2_init_sol']
# Out:
# (334.6501715525889,
#  [0,
#   107,
#   95,
#   14,
#   162,
#   183,
#   71,
#   25,
#   128,
#   150,
#   176,
#   92,
#   170,
#   166,
#   153,
#   87,
#   73,
#   67,
#   98,
#   116,
#   102,
#   192,
#   75,
#   122,
#   77,
#   136,
#   181,
#   46,
#   127,
#   7,
#   70,
#   93,
#   3,
#   197,
#   55,
#   33,
#   145,
#   187,
#   156,
#   186,
#   168,
#   18,
#   76,
#   44,
#   185,
#   32,
#   105,
#   158,
#   20,
#   109,
#   57,
#   177,
#   39,
#   131,
#   26,
#   178,
#   111,
#   2,
#   91,
#   96,
#   196,
#   188,
#   174,
#   198,
#   79,
#   23,
#   42,
#   130,
#   99,
#   135,
#   157,
#   31,
#   142,
#   139,
#   52,
#   190,
#   11,
#   124,
#   19,
#   118,
#   88,
#   120,
#   53,
#   15,
#   175,
#   51,
#   38,
#   146,
#   6,
#   16,
#   182,
#   100,
#   78,
#   106,
#   47,
#   86,
#   4,
#   58,
#   48,
#   184,
#   126,
#   34,
#   161,
#   171,
#   138,
#   159,
#   69,
#   151,
#   22,
#   17,
#   66,
#   125,
#   103,
#   104,
#   172,
# ...

# %%
exp3_results['trad_bnb_init_sol_cost'], exp3_results['trad_bnb_init_sol']
# Out:
# (334.6501715525889,
#  ([0,
#    107,
#    95,
#    14,
#    162,
#    183,
#    71,
#    25,
#    128,
#    150,
#    176,
#    92,
#    170,
#    166,
#    153,
#    87,
#    73,
#    67,
#    98,
#    116,
#    102,
#    192,
#    75,
#    122,
#    77,
#    136,
#    181,
#    46,
#    127,
#    7,
#    70,
#    93,
#    3,
#    197,
#    55,
#    33,
#    145,
#    187,
#    156,
#    186,
#    168,
#    18,
#    76,
#    44,
#    185,
#    32,
#    105,
#    158,
#    20,
#    109,
#    57,
#    177,
#    39,
#    131,
#    26,
#    178,
#    111,
#    2,
#    91,
#    96,
#    196,
#    188,
#    174,
#    198,
#    79,
#    23,
#    42,
#    130,
#    99,
#    135,
#    157,
#    31,
#    142,
#    139,
#    52,
#    190,
#    11,
#    124,
#    19,
#    118,
#    88,
#    120,
#    53,
#    15,
#    175,
#    51,
#    38,
#    146,
#    6,
#    16,
#    182,
#    100,
#    78,
#    106,
#    47,
#    86,
#    4,
#    58,
#    48,
#    184,
#    126,
#    34,
#    161,
# ...

# %%
exp3_results['mod_bnb_init_sol_cost'], exp3_results['mod_bnb_init_sol']
# Out:
# (334.6501715525889,
#  ([0,
#    107,
#    95,
#    14,
#    162,
#    183,
#    71,
#    25,
#    128,
#    150,
#    176,
#    92,
#    170,
#    166,
#    153,
#    87,
#    73,
#    67,
#    98,
#    116,
#    102,
#    192,
#    75,
#    122,
#    77,
#    136,
#    181,
#    46,
#    127,
#    7,
#    70,
#    93,
#    3,
#    197,
#    55,
#    33,
#    145,
#    187,
#    156,
#    186,
#    168,
#    18,
#    76,
#    44,
#    185,
#    32,
#    105,
#    158,
#    20,
#    109,
#    57,
#    177,
#    39,
#    131,
#    26,
#    178,
#    111,
#    2,
#    91,
#    96,
#    196,
#    188,
#    174,
#    198,
#    79,
#    23,
#    42,
#    130,
#    99,
#    135,
#    157,
#    31,
#    142,
#    139,
#    52,
#    190,
#    11,
#    124,
#    19,
#    118,
#    88,
#    120,
#    53,
#    15,
#    175,
#    51,
#    38,
#    146,
#    6,
#    16,
#    182,
#    100,
#    78,
#    106,
#    47,
#    86,
#    4,
#    58,
#    48,
#    184,
#    126,
#    34,
#    161,
# ...
